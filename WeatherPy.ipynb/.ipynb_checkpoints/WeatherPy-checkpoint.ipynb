# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# define count of pass throughs
count_one = 0
set_one = 1


# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 610

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

url = "https://api.openweathermap.org/data/2.5/weather?"

# Build query URL
query_url = url + "appid=" + weather_api_key + "&q=" + city

# Output File (CSV)
data_file = "output_data\cities.csv"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
    
# Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

# Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={weather_api_key}&units=metric"

# Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
    
#Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

# Add 1 to the record count
    record_count += 1

# Run an API request for each of the cities
try:
    city_weather = requests.get(city_url).json()
    city_lat = city_weather['coord']['lat']
    city_lng = city_weather['coord']['lon']
    city_max_temp = city_weather['main']['temp_max']
    city_humidity = city_weather['main']['humidity']
    city_clouds = city_weather['clouds']['all']
    city_wind = city_weather['wind']['speed']
    city_country = city_weather['sys']['country']
    city_date = city_weather['dt']
    
# Parse the JSON and retrieve data
 
# Get the temperature from the response
    print(f"The weather API responded with: {city_weather}.")
    
# Append the City information into city_data list
    city_data.append({"City": city, 
                     "Lat": city_lat, 
                     "Lng": city_lng, 
                     "Max Temp": city_max_temp,
                     "Humidity": city_humidity,
                     "Cloudiness": city_clouds,
                     "Wind Speed": city_wind,
                     "Country": city_country,
                     "Date": city_date})

# If an error is experienced, skip the city.
except:
    print("City not found. Skipping...")
    pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | praia
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | hovd
# Processing Record 8 of Set 1 | teruel
# Processing Record 9 of Set 1 | sibu
# Processing Record 10 of Set 1 | new norfolk
# Processing Record 11 of Set 1 | kruisfontein
# Processing Record 12 of Set 1 | bijie
# Processing Record 13 of Set 1 | saint-philippe
# Processing Record 14 of Set 1 | mildura
# Processing Record 15 of Set 1 | avarua
# Processing Record 16 of Set 1 | mount gambier
# Processing Record 17 of Set 1 | samusu
# Processing Record 18 of Set 1 | christchurch
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | alta floresta
# Processing Record 22 of Set 1 | carnarvon
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
import pandas as pd
data_file = "output_data\cities.csv"
# Define an empty list to fetch the weather data for each city
data_file_df = pd.read_csv(data_file)
# Show Record Count
data_file_df.count()
# Out:
# City_ID       577
# City_ID.2     577
# City_ID.1     577
# City          577
# Lat           577
# Lng           577
# Max Temp      577
# Humidity      577
# Cloudiness    577
# Wind Speed    577
# Country       574
# Date          577
# dtype: int64

# %%
# Display sample data
data_file_df.head()
# Out:
#    City_ID  City_ID.2  City_ID.1         City      Lat       Lng  Max Temp  \
# 0        0          0          0         faya  18.3851   42.4509     22.06
# 1        1          1          1      farsund  58.0948    6.8047     13.30
# 2        2          2          2  new norfolk -42.7826  147.0587     11.72
# 3        3          3          3    jamestown  42.0970  -79.2353      5.77
# 4        4          4          4      lanzhou  36.0564  103.7922     14.53
#
#    Humidity  Cloudiness  Wind Speed Country        Date
# 0        35          21        2.60      SA  1666108228
# 1       100           0        7.65      NO  1666108228
# 2        58          12        1.34      AU  1666108230
# 3        77         100        9.77      US  1666107934
# 4        48          59        1.20      CN  1666108230

# %%
# Export the City_Data into a csv
data_file_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
data_file_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
data_file_df.head()
# Out:
#          City_ID.3  City_ID.2  City_ID.1         City      Lat       Lng  \
# City_ID
# 0                0          0          0         faya  18.3851   42.4509
# 1                1          1          1      farsund  58.0948    6.8047
# 2                2          2          2  new norfolk -42.7826  147.0587
# 3                3          3          3    jamestown  42.0970  -79.2353
# 4                4          4          4      lanzhou  36.0564  103.7922
#
#          Max Temp  Humidity  Cloudiness  Wind Speed Country        Date
# City_ID
# 0           22.06        35          21        2.60      SA  1666108228
# 1           13.30       100           0        7.65      NO  1666108228
# 2           11.72        58          12        1.34      AU  1666108230
# 3            5.77        77         100        9.77      US  1666107934
# 4           14.53        48          59        1.20      CN  1666108230

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

plt.scatter(data_file_df['Lat'], data_file_df['Max Temp'], edgecolors='black')

# Incorporate the other graph properties
plt.title('City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(data_file_df['Lat'], data_file_df['Humidity'], edgecolors='black')

# Incorporate the other graph properties
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(data_file_df['Lat'], data_file_df['Cloudiness'], edgecolors='black')

# Incorporate the other graph properties
plt.title('City Latitude vs.Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(data_file_df['Lat'], data_file_df['Wind Speed'], edgecolors='black')

# Incorporate the other graph properties
plt.title('City Latitude vs.Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def create_lin_plots(df, x_col, y_col): 
    x_values = df[x_col]
    y_values = df[y_col]
    model = st.linregress(x_values, y_values)
    slope = model[0]
    intercept = model[1]
    regress_values = x_values * slope + intercept
    
    line_eq = f"y + {round(slope,2)} + x + {round(intercept,2)}"
    
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"red")
    
    #plt.annotate(line_eq,fontsize=15,color="red")
    plt.xlabel(x_col)
    plt.ylabel(y_col)
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = data_file_df.loc[data_file_df['Lat']>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#          City_ID.3  City_ID.2  City_ID.1       City      Lat       Lng  \
# City_ID
# 0                0          0          0       faya  18.3851   42.4509
# 1                1          1          1    farsund  58.0948    6.8047
# 3                3          3          3  jamestown  42.0970  -79.2353
# 4                4          4          4    lanzhou  36.0564  103.7922
# 6                6          6          6     albany  42.6001  -73.9662
#
#          Max Temp  Humidity  Cloudiness  Wind Speed Country        Date
# City_ID
# 0           22.06        35          21        2.60      SA  1666108228
# 1           13.30       100           0        7.65      NO  1666108228
# 3            5.77        77         100        9.77      US  1666107934
# 4           14.53        48          59        1.20      CN  1666108230
# 6           10.36        74          29        2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = data_file_df.loc[data_file_df['Lat']<=0]

# Display sample data
southern_hemi_df.head()
# Out:
#          City_ID.3  City_ID.2  City_ID.1          City      Lat       Lng  \
# City_ID
# 2                2          2          2   new norfolk -42.7826  147.0587
# 5                5          5          5       ushuaia -54.8000  -68.3000
# 7                7          7          7     carnarvon -24.8667  113.6333
# 9                9          9          9  saint-pierre -21.3393   55.4781
# 10              10         10         10      colorado -22.8375  -51.9731
#
#          Max Temp  Humidity  Cloudiness  Wind Speed Country        Date
# City_ID
# 2           11.72        58          12        1.34      AU  1666108230
# 5            8.81        81          75        3.09      AR  1666108231
# 7           20.02        76           0        7.46      AU  1666108232
# 9           22.82        68           0        5.14      RE  1666108236
# 10          20.36        86          96        4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
import pandas as pd
import sklearn.datasets as dta
import scipy.stats as st
import matplotlib.pyplot as plt
from scipy.stats import linregress
import numpy as np

create_lin_plots(northern_hemi_df, 'Lat', 'Max Temp')

# %%
# Linear regression on Southern Hemisphere
import pandas as pd
import sklearn.datasets as dta
import scipy.stats as st
import matplotlib.pyplot as plt
from scipy.stats import linregress
import numpy as np

create_lin_plots(southern_hemi_df, 'Lat', 'Max Temp')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
"There is a strong correlation between Max Temp and Latitude as shown by the concetration of dots along the line for both hemispheres"
# Out:
# 'There is a strong correlation between Max Temp and Latitude as shown by the concetration of dots along the line for both hemispheres'

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
import pandas as pd
import sklearn.datasets as dta
import scipy.stats as st
import matplotlib.pyplot as plt
from scipy.stats import linregress
create_lin_plots(northern_hemi_df,'Lat','Humidity')

# %%
# Southern Hemisphere
import pandas as pd
import sklearn.datasets as dta
import scipy.stats as st
import matplotlib.pyplot as plt
from scipy.stats import linregress
create_lin_plots(southern_hemi_df,'Lat','Humidity')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
"There is a strong correlation between Humidity and Latitude as shown by the concetration of dots along the line for northern hemisphere and least for southern"
# Out:
# 'There is a strong correlation between Humidity and Latitude as shown by the concetration of dots along the line for northern hemisphere and least for southern'

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# import pandas as pd
import sklearn.datasets as dta
import scipy.stats as st
import matplotlib.pyplot as plt
from scipy.stats import linregress

create_lin_plots(northern_hemi_df,'Lat','Cloudiness')

# %%
# Southern Hemisphere
import pandas as pd
import sklearn.datasets as dta
import scipy.stats as st
import matplotlib.pyplot as plt
from scipy.stats import linregress

create_lin_plots(southern_hemi_df,'Lat','Cloudiness')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
"There is a weaker correlation between Cloudiness and Latitude as shown by the concetration of dots along the line for both hemispheres"
# Out:
# 'There is a weaker correlation between Cloudiness and Latitude as shown by the concetration of dots along the line for both hemispheres'

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
import pandas as pd
import sklearn.datasets as dta
import scipy.stats as st
import matplotlib.pyplot as plt
from scipy.stats import linregress
create_lin_plots(northern_hemi_df,'Lat','Wind Speed')

# %%
# Southern Hemisphere
# import pandas as pd
import sklearn.datasets as dta
import scipy.stats as st
import matplotlib.pyplot as plt
from scipy.stats import linregress
create_lin_plots(southern_hemi_df,'Lat','Wind Speed')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
"Linear relationship is stronger for northern hemisphere vs southern on Wind Speed and Latitude"
# Out:
# 'Linear relationship is stronger for northern hemisphere vs southern on Wind Speed and Latitude'
